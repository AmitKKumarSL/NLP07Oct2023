# %%
# !pip install fuzzywuzzy

# %%
import warnings
warnings.filterwarnings('ignore')

from fuzzywuzzy import process

# %%
ipl_teams = ['Chennai Super Kings',
             'Royal Challengers Bangalore',
             'Delhi Capitals',
             'Kolkata Knight Riders',
             'Punjab Kings',
             'Rajasthan Royals',
             'Sunrisers Hyderabad']

# %%
#Play -> #Stay
# First remove P and then insert S in place of P (2 operations)
# Remove l and insert t (2 operations)

# %%
statement = 'Kolkata Knights beat dilli team by 30 runs'
process.extract(statement, ipl_teams, limit=2)

# %%
process.extract("This is NLP class", ["This is NLP Class"], limit=2)

# %%
diseases = ['Heart Attack', 'Brain Tumor', 'Lung Cancer', 'Fever', 'Throat Infection']
instruments = [' electrocardiograph' , ' Sterilizers', ' Defibrillators', 'Thermometer', 'ICU']

# %%
statement = "An electrocardiogram (ECG) is a medical test that detects cardiac (heart) abnormalities by measuring the electrical activity generated by the heart as it contracts. The machine that records the patient’s ECG is called an electrocardiograph."

# %%
process.extract(statement, diseases, limit=2)

# %%
process.extract(statement, instruments, limit=3)
